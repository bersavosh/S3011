# %% [markdown]
# # My first notebook
#
# ## Note regarding Google Colab
#
# If we need a package installed in Google Colab, we can do it with:
#
# ```
# !pip install pandas
# ```
#
# Or if we want to use the `uv` setup:
# ```
# !pip install uv
# !wget https://raw.githubusercontent.com/bersavosh/S3011/refs/heads/main/pyproject.toml
# !uv pip install -r pyproject.toml
# ```

# %% [markdown]
# ## Notebooks are like Rmd files in RStudio
#
# Other that that, we can run cells here like RStudio:

# %%
import pandas as pd
import matplotlib.pyplot as plt

DATA_DIR = 'https://raw.githubusercontent.com/bersavosh/S3011/main/data/'

# %% [markdown]
# ## Our data

# %%
data = pd.read_csv(DATA_DIR+'movement-speeds-hourly-san-francisco-2020-1_first4k.csv')
data
# Out:
#       Unnamed: 0  year  month  day  hour             utc_timestamp  \
# 0           3282  2020      1   11    18  2020-01-12T02:00:00.000Z
# 1            889  2020      1    5     3  2020-01-05T11:00:00.000Z
# 2           3916  2020      1   12    15  2020-01-12T23:00:00.000Z
# 3           2573  2020      1   18    17  2020-01-19T01:00:00.000Z
# 4           2693  2020      1   12    11  2020-01-12T19:00:00.000Z
# ...          ...   ...    ...  ...   ...                       ...
# 3995        3408  2020      1   11    13  2020-01-11T21:00:00.000Z
# 3996         532  2020      1    1    12  2020-01-01T20:00:00.000Z
# 3997        2292  2020      1    8    19  2020-01-09T03:00:00.000Z
# 3998         303  2020      1   31    22  2020-02-01T06:00:00.000Z
# 3999        2642  2020      1    9     8  2020-01-09T16:00:00.000Z
#
#                                     segment_id  \
# 0     92291c5c7071877515e9f4b4174f6a6d9164ccee
# 1     fb85985b26c30733a51c28cf99f5c341dcbe40f2
# ...

# %% [markdown]
# ## Making a simple plot
#
# Implict

# %%
plt.plot(data['speed_mph_mean'])

# %% [markdown]
# Explicit

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot()
ax.plot(data['speed_mph_mean'])

# %% [markdown]
# Now customizing the plot

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot()
ax.plot(data['speed_mph_mean'], ':s', markersize=2, linewidth=0.5, color='green')
ax.set_xlabel('Trip Number')
ax.set_ylabel('Mean speed (mph)')
# Out:
# Text(0, 0.5, 'Mean speed (mph)')

# %% [markdown]
# ## Saving: raster versus vector rendering

# %%
fig.savefig('plot_raster.jpg')
fig.savefig('plot_vector.pdf')
